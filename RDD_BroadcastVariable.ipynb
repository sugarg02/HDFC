# %% [markdown]
# #### RDD Operations Exercise customer and salestxn data set with broadcase variable
#
# We have customer details in a file - customers.tsv and sales transactions details in another file - salestxn.tsv.
# Sales transactions contain only customer id but not name. Also the transactions may have multiple entries for a particular item if customer made separate transactions. We have to generate output that contain customer id, customer name along with the product name, product id, price, total quantity ordered and total amount paid.
#
# Since customer file is smaller (with 1244 records) and sales transactions file is larger (172198 records) we will put customer details in a variable and broadcast it across the cluster in our code. We will use this broadcast variable to add the customer id and name to the sales transactions.
#
# In the application flow we also need to aggregate the sales transactions of the same product in cases where a customer ordered as multiple transactions.

# %% [markdown]
# Import findspark with spark installation path and initialize

# %%
import os
os.environ['PYSPARK_DRIVER_PYTHON'] = '/opt/anaconda3/bin/python3.7'
os.environ['PYSPARK_PYTHON'] = '/opt/anaconda3/bin/python3.7'
os.environ["SPARK_HOME"] = '/opt/cloudera/parcels/CDH/lib/spark'
import findspark
findspark.init()
import findspark
findspark.init()

# %% [markdown]
# Import PySpark and create SparkContext

# %%
import pyspark
sc = pyspark.SparkContext(appName='BroadcastVar')

# %% [markdown]
# Read the customers data input file to create an input RDD

# %%
custRDD1=sc.textFile("customers.tsv")

# %% [markdown]
# Display count and a sample of the RDD elements for debugging purposes. The RDD elements are the lines of type string from the input file.

# %%
custRDD1.count()
# Out:
# 1244

# %% [markdown]
# ###### We need to transform the RDD elements into key,value pairs with the required key and value.
#
# The function for custRDD:
#  - Splits the input string at tabs.
#  - Uses customer id as the key and customer name as the value
#  - Then returns the string constructed as pair RDD

# %%
def make_cust_pairRDD(str):
    line = str.split('\t')
    return (line[0], line[1])

# %% [markdown]
# Use map lambda function to transform each element of RDD1 to key,value pair using the above function.

# %%
custRDD2=custRDD1.map(lambda line: make_cust_pairRDD(line))

# %% [markdown]
# Normally persist is done when we have to do several transformations on an RDD. It will avoid recomputing the RDD from the beginning for each transformation.

# %%
custRDD2.persist()
# Out:
# PythonRDD[3] at RDD at PythonRDD.scala:53

# %%
custDict=custRDD2.collectAsMap()

# %% [markdown]
# The RDD operation collectAsMap returns the pairRDD as a dictionary (referred to as Map in other programming languages).

# %%
custDict['6342']
# Out:
# 'Kimberly Blair'

# %%
custDict['11599']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-02b1df2fad8c> in <module>
# ----> 1 custDict['11599']
#
# KeyError: '11599'

# %% [markdown]
# Since some customer details are missing in the customers files we better use .get method to get the customer name for a given customer id.

# %%
custDict.get('6342')
# Out:
# 'Kimberly Blair'

# %%
custDict.get('11599')

# %% [markdown]
# We will define a broadcast variable - custDictBroadcast and make our custDict as the broadcast variable in our application.

# %%
custDictBroadcast=sc.broadcast(custDict)

# %%
type(custDictBroadcast)
# Out:
# pyspark.broadcast.Broadcast

# %%
custDictBroadcast.value
# Out:
# {'11039': 'Mary Torres',
#  '5623': 'Jose Haley',
#  '5829': 'Mary Smith',
#  '6336': 'Richard Maddox',
#  '1708': 'Margaret Booth',
#  '10227': 'Mary Henderson',
#  '839': 'Lisa Walker',
#  '7604': 'Jonathan Hill',
#  '6485': 'Carolyn Sheppard',
#  '4737': 'Mary Mendoza',
#  '5973': 'Michael Smith',
#  '9205': 'James Holmes',
#  '138': 'Mary Dawson',
#  '371': 'Adam Marquez',
#  '9285': 'Gloria Smith',
#  '1209': 'Mary Webb',
#  '3021': 'Nancy Alvarado',
#  '3354': 'Russell Flores',
#  '11684': 'Denise Smith',
#  '11144': 'Jose Dickerson',
#  '5252': 'Mary Smith',
#  '8688': 'Michelle Rose',
#  '8900': 'Russell Peterson',
#  '5577': 'Mary Smith',
#  '11161': 'Mary Pennington',
#  '4494': 'Mary Smith',
#  '7565': 'Jean Donovan',
#  '11218': 'Louis Novak',
#  '10124': 'Mary Santos',
#  '6052': 'Mary Harding',
#  '9756': 'Mary White',
#  '5748': 'Shawn Mann',
#  '11748': 'James Smith',
#  '3852': 'Roy Potts',
#  '668': 'Phillip Lewis',
#  '1236': 'Virginia Robertson',
#  '6991': 'Mary Smith',
#  '6941': 'Jeffrey Palmer',
#  '12425': 'Mary Smith',
#  '5013': 'Mary Peters',
#  '759': 'Donna Smith',
#  '8829': 'Charles Smith',
#  '9359': 'Nancy Campos',
#  '6252': 'Kevin Smith',
#  '9510': 'Steven Wright',
#  '1745': 'Mary Smith',
#  '5093': 'Sara Rice',
#  '11151': 'Harold Walker',
#  '12431': 'Mary Rios',
#  '8582': 'Edward Smith',
#  '11444': 'Kathleen Patrick',
#  '6087': 'Evelyn Smith',
#  '9208': 'John Gillespie',
#  '10937': 'Mary Smith',
#  '900': 'George Smith',
#  '4311': 'Albert Collins',
#  '10485': 'Mary Smith',
#  '9552': 'Richard Wilkerson',
#  '7440': 'James French',
#  '5619': 'Mary Smith',
#  '1326': 'Mary Edwards',
#  '8364': 'Michael Smith',
#  '5120': 'Mary Smith',
#  '6309': 'Cynthia Smith',
#  '951': 'Mary Young',
#  '8951': 'Mary Baker',
#  '1662': 'George Smith',
#  '6631': 'Mary Morrow',
#  '4717': 'Mary Sanders',
#  '9643': 'Olivia Smith',
#  '434': 'Michael Torres',
#  '9818': 'Mary Avila',
#  '8846': 'Thomas Smith',
#  '3135': 'Helen Ward',
#  '3589': 'Mary Smith',
#  '11709': 'Mary Harrison',
#  '3540': 'Nicole Bishop',
#  '8506': 'Elizabeth Smith',
#  '10695': 'Andrew Smith',
#  '6237': 'Bobby Anderson',
#  '6748': 'Keith Smith',
#  '12209': 'Jerry Hobbs',
#  '9119': 'Mary Smith',
#  '6879': 'Mark Mcguire',
#  '4201': 'Mary Smith',
#  '9481': 'Julie Smith',
#  '1634': 'Jason Riggs',
#  '10413': 'Mary Smith',
#  '4085': 'Mary Carr',
#  '7965': 'Mary Hunter',
#  '12110': 'Lisa Smith',
#  '8705': 'Patricia Smith',
#  '9440': 'Mary Leonard',
#  '11345': 'John Mathis',
#  '236': 'Ashley Clark',
#  '8231': 'Mary Jones',
#  '4971': 'Mary Hogan',
#  '1156': 'Mary Terrell',
#  '12337': 'Mary Davis',
#  '4604': 'Mary Pearson',
#  '131': 'Brenda Cline',
#  '11261': 'Robert Smith',
#  '5612': 'Mary Huang',
#  '7535': 'Sarah Browning',
#  '530': 'Mary Smith',
#  '5960': 'Margaret Smith',
#  '11479': 'Debra Johnson',
#  '11799': 'Mary Tate',
#  '1076': 'Tyler Thompson',
#  '5140': 'Mary Walton',
#  '2251': 'Gregory Manning',
#  '1598': 'Mary Green',
#  '1170': 'Daniel Villarreal',
#  '129': 'Crystal Smith',
#  '6039': 'Theresa Mills',
#  '1220': 'Samantha Terry',
#  '10189': 'Harry Chung',
#  '2300': 'Patrick Williamson',
#  '3669': 'Mary Soto',
#  '580': 'Kimberly Lee',
#  '6099': 'Helen Smith',
#  '4327': 'Sarah Greene',
#  '10447': 'Mary Smith',
#  '9377': 'Carol Leach',
#  '3164': 'Karen Smith',
#  '31': 'Mary Byrd',
#  '1515': 'Crystal Peters',
#  '10019': 'Victoria Obrien',
#  '9674': 'Sean Smith',
#  '2527': 'Heather Smith',
#  '6101': 'Mary Smith',
#  '2159': 'Kimberly Sweeney',
#  '12052': 'Mary Burke',
#  '11697': 'Jessica Thomas',
#  '11234': 'Martha Smith',
#  '1295': 'Theresa Lopez',
#  '10826': 'Mary Hanson',
#  '5274': 'Michael Beard',
#  '10225': 'Diane English',
#  '9461': 'Mary Hoover',
#  '2420': 'Mary Smith',
#  '10963': 'Amber Smith',
#  '11107': 'Melissa Smith',
#  '8158': 'Donald Pugh',
#  '6644': 'Judith Phillips',
#  '8641': 'David Smith',
#  '5397': 'Mary Nelson',
#  '4814': 'Paul Suarez',
#  '5921': 'Mary Buchanan',
#  '1805': 'Mary Porter',
#  '10282': 'Mary Roberts',
#  '1591': 'Charles Johnson',
#  '11981': 'Mary Smith',
#  '2168': 'Mary Reynolds',
#  '7983': 'Heather Merritt',
#  '8942': 'Robert Smith',
#  '5725': 'Mary Smith',
#  '12357': 'Harry Smith',
#  '8530': 'William Smith',
#  '8892': 'Russell Dennis',
#  '7716': 'David Middleton',
#  '8974': 'Mary Schultz',
#  '5413': 'Mary Smith',
#  '4617': 'Jason Keller',
#  '4234': 'Dorothy Spencer',
#  '7049': 'Justin Graham',
#  '8784': 'Jonathan Smith',
#  '1870': 'Tiffany Greer',
#  '10065': 'Betty Padilla',
#  '6694': 'John Evans',
#  '1215': 'Joe Hart',
#  '7544': 'Barbara Smith',
#  '11788': 'Dennis Marsh',
#  '7173': 'Mary Glass',
#  '3308': 'Aaron Smith',
#  '1613': 'Mary Smith',
#  '4278': 'Andrew Smith',
#  '369': 'Madison Sheppard',
#  '3437': 'Mary Massey',
#  '3846': 'Ronald Lewis',
#  '7458': 'Philip Williams',
#  '7622': 'Mary Hodges',
#  '8180': 'Albert Smith',
#  '5907': 'Mary Proctor',
#  '10476': 'John Hodges',
#  '3557': 'Benjamin Clarke',
#  '3610': 'Jordan Smith',
#  '651': 'Mary Smith',
#  '8757': 'Tyler Gutierrez',
#  '5473': 'Randy Smith',
#  '12057': 'Tyler Sims',
#  '4074': 'Barbara Smith',
#  '10243': 'Donna Anderson',
#  '11595': 'Zachary Jones',
#  '11893': 'Mary Graves',
#  '2402': 'Mary Smith',
#  '847': 'Jerry Ferguson',
#  '10303': 'Shawn Smith',
#  '8695': 'Larry Thomas',
#  '3440': 'Mary Edwards',
#  '208': 'Mary Smith',
#  '3400': 'Frank Lewis',
#  '6075': 'Mary Smith',
#  '281': 'Stephanie Smith',
#  '2643': 'David Smith',
#  '253': 'Nancy Smith',
#  '6939': 'Amber Jimenez',
#  '11245': 'Debra Washington',
#  '6262': 'Mary Brennan',
#  '3167': 'Janice Ward',
#  '8568': 'Catherine Beck',
#  '337': 'Mary Neal',
#  '10207': 'Janet Smith',
#  '7677': 'Mary Bonilla',
#  '1712': 'Megan Brown',
#  '6529': 'Aaron Smith',
#  '1342': 'Laura Savage',
#  '2791': 'Martha Smith',
#  '3713': 'Helen Smith',
#  '11916': 'Mary Smith',
#  '1069': 'Mary Daniel',
#  '9919': 'Mary Daniel',
#  '10172': 'Mary Pugh',
#  '5188': 'Margaret Grant',
#  '2459': 'Robert Lyons',
#  '4659': 'Paul Smith',
#  '4095': 'Mary Lewis',
#  '2099': 'Dylan Preston',
#  '1582': 'Carol Merritt',
#  '8791': 'Beverly Ali',
#  '10175': 'Michael Gibson',
#  '665': 'Mary Smith',
#  '11363': 'Frank Paul',
#  '7580': 'Joseph Porter',
#  '4261': 'Amber Nguyen',
#  '11399': 'Mary Martinez',
#  '6356': 'Mary Smith',
#  '4539': 'Jacqueline James',
#  '10968': 'Diana Smith',
#  '2590': 'Mary Andrade',
#  '4144': 'David Collins',
#  '12387': 'Mary Archer',
#  '4884': 'Mary Wall',
#  '5196': 'Mary Smith',
#  '5046': 'Mary Smith',
#  '8469': 'Amanda Smith',
#  '2486': 'Anna Mcdonald',
#  '10087': 'Mary Myers',
#  '7840': 'Mary Smith',
#  '8508': 'Eugene Smith',
#  '3723': 'Mary Jones',
#  '3854': 'Mary Gilbert',
#  '656': 'Julie Smith',
#  '467': 'James Smith',
#  '11663': 'Emily Hill',
#  '11505': 'Michael Schultz',
#  '5377': 'Crystal Jones',
#  '2901': 'Emma Davis',
#  '5161': 'Mary Zavala',
#  '11404': 'Helen Cook',
#  '8867': 'Justin Bonilla',
#  '10460': 'Mary Morrison',
#  '5915': 'Mary Hamilton',
#  '8498': 'Joseph Pennington',
#  '5534': 'Elizabeth Smith',
#  '4929': 'Janet Harvey',
#  '9474': 'Keith Moore',
#  '9313': 'Mary Krause',
#  '5895': 'Mary Sullivan',
#  '349': 'Aaron Berger',
#  '979': 'Mary Smith',
#  '9272': 'Ronald Blackwell',
#  '93': 'Mary Robbins',
#  '11181': 'Mary Hernandez',
#  '6226': 'John Jones',
#  '12334': 'Michael Robertson',
#  '11526': 'Dorothy Crawford',
#  '11114': 'Mary Owens',
#  '5755': 'Marie Shah',
#  '12116': 'Mary Shea',
#  '6455': 'Ethan Brown',
#  '11628': 'Jennifer Edwards',
#  '1913': 'Ethan Smith',
#  '5229': 'Thomas Butler',
#  '9813': 'Mary Roth',
#  '3750': 'Mary Smith',
#  '5778': 'Evelyn Smith',
#  '6520': 'Judy Foster',
#  '917': 'Andrew Glenn',
#  '1077': 'Mary Williamson',
#  '11487': 'Cheryl Evans',
#  '9139': 'Mary Galvan',
#  '2322': 'Zachary Smith',
#  '11845': 'Mary Weaver',
#  '11743': 'Alexander Smith',
#  '6532': 'Mary Dixon',
#  '11173': 'Kathleen Mayer',
#  '9988': 'Brenda Simmons',
#  '10952': 'Mary Suarez',
#  '4301': 'Emily Smith',
#  '9957': 'Charles Bennett',
#  '7323': 'Sarah Neal',
#  '9948': 'Susan Day',
#  '1095': 'Mary Owens',
#  '5448': 'Kelly English',
#  '9317': 'Mary Smith',
#  '664': 'Bobby Jimenez',
#  '2559': 'Donna Hall',
#  '5249': 'Robert Huffman',
#  '5720': 'Peter Cooper',
#  '6600': 'Arthur Smith',
#  '8379': 'Martha Kelly',
#  '8020': 'Joan Davis',
#  '10407': 'William Clay',
#  '6196': 'Jennifer Stewart',
#  '493': 'Joseph Smith',
#  '4822': 'Mary Smith',
#  '6232': 'Janet Webb',
#  '2370': 'Mary Hurley',
#  '1024': 'Paul Alvarado',
#  '2161': 'Mary Mercer',
#  '658': 'Peter Farley',
#  '8765': 'Gary Smith',
#  '8346': 'Mary Wright',
#  '321': 'David Smith',
#  '5119': 'Brenda Miller',
#  '9031': 'Mary Brown',
#  '6072': 'Stephen Smith',
#  '8869': 'Thomas Lambert',
#  '3278': 'Patrick Anderson',
#  '12319': 'Laura Woodward',
#  '11385': 'Mary Stewart',
#  '7183': 'Anna Smith',
#  '5862': 'David Cantu',
#  '3734': 'Katherine Smith',
#  '4041': 'Mary Santiago',
#  '3923': 'Mary King',
#  '316': 'Mary Smith',
#  '8152': 'Nicholas Smith',
#  '1050': 'Gloria Marshall',
#  '3281': 'Teresa Werner',
#  '11013': 'Andrew Nguyen',
#  '11888': 'Frank Barrett',
#  '539': 'Marilyn Smith',
#  '4535': 'Ruth Brown',
#  '11589': 'Mary Anderson',
#  '10233': 'Mary Bennett',
#  '4202': 'Kimberly Griffin',
#  '2471': 'Olivia Smith',
#  '5952': 'Jacob Smith',
#  '829': 'Mary Smith',
#  '11587': 'Alice Stewart',
#  '10652': 'Tammy Smith',
#  '6342': 'Kimberly Blair',
#  '3017': 'Frank Thompson',
#  '9141': 'Ronald Clark',
#  '2496': 'Mary Smith',
#  '9011': 'Mary Smith',
#  '8939': 'Mary Smith',
#  '2938': 'Nicole Smith',
#  '9326': 'Linda Hess',
#  '5222': 'Evelyn Vincent',
#  '4014': 'Mary Smith',
#  '11954': 'Mary Smith',
#  '10224': 'Betty Lawson',
#  '11808': 'Sharon Schultz',
#  '790': 'Martha Robinson',
#  '2273': 'Jacob Smith',
#  '7112': 'Mark Harris',
#  '11328': 'Patricia Johns',
#  '4012': 'Mary Smith',
#  '4060': 'Mary Smith',
#  '1382': 'Mary Aguilar',
#  '7583': 'Mary Pace',
#  '12332': 'Kelly Jones',
#  '3784': 'Mary Sharp',
#  '4544': 'Mary Warren',
#  '11019': 'Mary Zamora',
#  '3794': 'Julia Smith',
#  '2942': 'Mary Taylor',
#  '6866': 'Wayne Smith',
#  '16': 'Tiffany Smith',
#  '4592': 'Mary Sanchez',
#  '9007': 'Mary Maynard',
#  '11207': 'Gerald Smith',
#  '12030': 'Linda Smith',
#  '8217': 'Virginia Cantrell',
#  '5797': 'Roy Smith',
#  '2144': 'Mary Trevino',
#  '10547': 'Amy Ruiz',
#  '9814': 'Daniel Smith',
#  '4143': 'Mary Smith',
#  '9805': 'Mary Camacho',
#  '7955': 'Mary Rios',
#  '4518': 'Jennifer Smith',
#  '9778': 'Kathy Maddox',
#  '5962': 'Jordan Smith',
#  '12219': 'Beverly Nguyen',
#  '1533': 'Linda Kent',
#  '1146': 'Alice Evans',
#  '2941': 'Brian Martinez',
#  '59': 'Douglas James',
#  '10377': 'Anna Smith',
#  '8456': 'Mary Smith',
#  '12059': 'Shawn Clark',
#  '4124': 'Jerry Larsen',
#  '2564': 'Phillip Smith',
#  '1518': 'Jessica Smith',
#  '461': 'Mary Smith',
#  '10876': 'William Beasley',
#  '12262': 'Michael Gray',
#  '1942': 'Joseph Moran',
#  '1335': 'Mary Smith',
#  '8783': 'Eric Ramsey',
#  '11342': 'Steven Booker',
#  '10668': 'Mary Smith',
#  '1780': 'Larry Sharp',
#  '11786': 'Mary Macdonald',
#  '4319': 'Melissa Smith',
#  '548': 'Ryan Horton',
#  '2043': 'Mary Smith',
#  '11513': 'David Smith',
#  '9533': 'Mary Hess',
#  '7644': 'Mary Freeman',
#  '8211': 'Ronald Mcneil',
#  '1835': 'Mary Smith',
#  '11696': 'Mary Smith',
#  '2483': 'Mary Lane',
#  '3861': 'Mary Smith',
#  '3343': 'Vincent Smith',
#  '6339': 'Mary Bush',
#  '9371': 'Mary Patterson',
#  '10059': 'Julia Smith',
#  '1075': 'Michelle Smith',
#  '1677': 'Virginia Robles',
#  '8995': 'Mary Smith',
#  '645': 'Mary Conner',
#  '8260': 'Teresa Berg',
#  '3148': 'Mary Barrett',
#  '10688': 'Pamela Rivers',
#  '8985': 'Helen Russo',
#  '3484': 'Rebecca Hunter',
#  '4418': 'Mary Mills',
#  '7602': 'Brian Mitchell',
#  '12287': 'Robert Lee',
#  '64': 'Mary Reynolds',
#  '5788': 'Mary Barrera',
#  '7198': 'Mary Day',
#  '5741': 'Mary Spencer',
#  '11805': 'Anthony Smith',
#  '12276': 'Martha Smith',
#  '4843': 'Mary Sandoval',
#  '562': 'Mary Smith',
#  '1283': 'Ashley White',
#  '10269': 'Mary Flowers',
#  '803': 'James Hartman',
#  '2994': 'Mary Lawson',
#  '6372': 'Henry Smith',
#  '9614': 'Patricia Frazier',
#  '555': 'Mildred Smith',
#  '8166': 'Patricia Smith',
#  '1247': 'Robert Montgomery',
#  '9226': 'Grace Davis',
#  '6193': 'Mary Li',
#  '4768': 'Amanda Hays',
#  '5178': 'Mary Willis',
#  '6443': 'Mary Salazar',
#  '10827': 'Janice Smith',
#  '6646': 'Mary Lopez',
#  '8243': 'Gary Walker',
#  '4224': 'Mary Smith',
#  '7511': 'Mary Park',
#  '4727': 'Amanda Estes',
#  '1992': 'Mary Mann',
#  '6033': 'Mary Pitts',
#  '9271': 'Christopher Smith',
#  '7868': 'Michael Smith',
#  '6115': 'Mary Smith',
#  '551': 'Doris Weaver',
#  '10924': 'Steven Smith',
#  '1121': 'Kathleen Smith',
#  '6293': 'Mary Porter',
#  '560': 'Emma Smith',
#  '7913': 'Randy Edwards',
#  '2213': 'Henry Castaneda',
#  '2574': 'Martha Ward',
#  '12068': 'Mary Smith',
#  '5401': 'Amber Smith',
#  '3683': 'Mary Fernandez',
#  '2820': 'Roy Smith',
#  '4108': 'Mary Smith',
#  '3754': 'Mary Sims',
#  '4555': 'Mary Smith',
#  '3613': 'Mary York',
#  '11795': 'Eugene Lewis',
#  '3176': 'Donna Smith',
#  '1853': 'Mary Austin',
#  '6930': 'Paul Morton',
#  '4267': 'Ashley Peters',
#  '80': 'Joe Parsons',
#  '7674': 'Mary Smith',
#  '4156': 'Mary Smith',
#  '8433': 'Sharon Short',
#  '2246': 'Mary Lewis',
#  '2940': 'Mary Smith',
#  '6769': 'Katherine Riley',
#  '12349': 'Mary Arnold',
#  '8408': 'Patrick Smith',
#  '3572': 'Mary Bennett',
#  '10508': 'Angela Meadows',
#  '6938': 'Kathleen Smith',
#  '9639': 'Mary Smith',
#  '5489': 'Teresa Smith',
#  '1979': 'Kimberly Kramer',
#  '4086': 'James Smith',
#  '4558': 'Jennifer Smith',
#  '1057': 'Richard Haynes',
#  '9657': 'Roy Williams',
#  '5001': 'Ann Waller',
#  '9171': 'Mary Bruce',
#  '1369': 'Mary Walker',
#  '7399': 'Mary Valdez',
#  '5987': 'Mary Smith',
#  '4064': 'Mildred Smith',
#  '11032': 'Mary Welch',
#  '2456': 'Joan Donaldson',
#  '6410': 'Stephanie Smith',
#  '409': 'Kevin Smith',
#  '4255': 'Brittany Smith',
#  '3968': 'Catherine Pacheco',
#  '3324': 'Mary Smith',
#  '7844': 'Scott Smith',
#  '9321': 'Mary Silva',
#  '2504': 'Mary Smith',
#  '8943': 'Brian Yates',
#  '5193': 'Amanda Stokes',
#  '9915': 'Mary Pollard',
#  '7549': 'Timothy Ellison',
#  '6989': 'Mary Smith',
#  '1694': 'Mary Thompson',
#  '1989': 'Richard Leach',
#  '1092': 'George Garcia',
#  '10711': 'Cynthia Campbell',
#  '8606': 'Mary Shah',
#  '1895': 'George Myers',
#  '8643': 'Mary Valenzuela',
#  '10778': 'Mary Mercado',
#  '9705': 'Patricia Smith',
#  '2479': 'Mary Miller',
#  '5814': 'Debra Smith',
#  '1399': 'Mary Smith',
#  '10073': 'Megan Lee',
#  '3987': 'Alice Allen',
#  '12417': 'Mary Smith',
#  '12165': 'Christine Smith',
#  '8798': 'Maria Smith',
#  '7491': 'Sharon Dominguez',
#  '12346': 'Mary Smith',
#  '3984': 'Brenda Webster',
#  '1797': 'Carolyn Smith',
#  '4638': 'Donald Hayes',
#  '851': 'Mary Snyder',
#  '8613': 'Mary Kirk',
#  '8786': 'Joseph Smith',
#  '8053': 'Mary Dennis',
#  '7786': 'Mary Price',
#  '3502': 'Mary Smith',
#  '26': 'Johnny Hood',
#  '189': 'Angela Peterson',
#  '3077': 'Albert Rush',
#  '8348': 'Mary Maddox',
#  '10237': 'Margaret Davis',
#  '2773': 'Linda Hale',
#  '3431': 'Mary Berger',
#  '9454': 'Mary Carson',
#  '11698': 'Julie Tran',
#  '1653': 'Brian Gates',
#  '5391': 'Mary Smith',
#  '12271': 'Mary Small',
#  '10530': 'Mary Smith',
#  '6906': 'Rebecca Watkins',
#  '3932': 'Evelyn Smith',
#  '9261': 'Patrick Burnett',
#  '6268': 'Mary Summers',
#  '8387': 'Richard Fuentes',
#  '4340': 'Stephen Beck',
#  '6346': 'Mary Cooley',
#  '4465': 'John Sanchez',
#  '354': 'Edward Peterson',
#  '10642': 'James Smith',
#  '7909': 'Aaron Mann',
#  '9490': 'Mary Glass',
#  '9741': 'Judith King',
#  '9546': 'Louis Holland',
#  '8905': 'Donna Smith',
#  '2922': 'Madison Russo',
#  '5126': 'Karen Roberts',
#  '11314': 'Ashley Mclaughlin',
#  '7649': 'Mary Lopez',
#  '3468': 'Mary Romero',
#  '9890': 'Christian Luna',
#  '12312': 'Jessica Figueroa',
#  '10894': 'Mary Castillo',
#  '7553': 'Mary Thompson',
#  '245': 'Deborah Smith',
#  '8658': 'Mary Allen',
#  '7297': 'Philip Smith',
#  '714': 'Mark Beltran',
#  '2150': 'Andrea Lawson',
#  '10371': 'Joseph Smith',
#  '12035': 'William Mcdaniel',
#  '8556': 'Daniel Pruitt',
#  '8089': 'Evelyn Smith',
#  '707': 'Shawn Ortiz',
#  '6439': 'Mary Booth',
#  '11373': 'William Cohen',
#  '653': 'Jason Haas',
#  '11185': 'Barbara Smith',
#  '9310': 'Timothy Smith',
#  '1334': 'Roger Dunlap',
#  '2183': 'Richard Smith',
#  '8184': 'Mary Smith',
#  '8547': 'Melissa Cunningham',
#  '6998': 'Catherine Jimenez',
#  '6483': 'Mary Smith',
#  '7614': 'Paul Martin',
#  '3425': 'Andrea Smith',
#  '5073': 'Mary Frazier',
#  '9097': 'Mary Padilla',
#  '4482': 'Randy Elliott',
#  '5513': 'Mary Smith',
#  '11751': 'Mary Smith',
#  '5244': 'Alexander Meyer',
#  '12118': 'Mary Zimmerman',
#  '3206': 'Mary Smith',
#  '8891': 'Michael Smith',
#  '2990': 'Michael Smith',
#  '6463': 'Mary Smith',
#  '11033': 'Matthew Fields',
#  '6800': 'Christine Ford',
#  '3162': 'Wayne Smith',
#  '2038': 'Tammy Smith',
#  '8079': 'Mary Burnett',
#  '11873': 'Joe Collier',
#  '10693': 'Andrea Sparks',
#  '1397': 'Dorothy Carter',
#  '3668': 'Judy Smith',
#  '6497': 'Mary Lee',
#  '5435': 'Mary Smith',
#  '8630': 'Jeremy Smith',
#  '6654': 'Mary Simmons',
#  '5234': 'Shirley Humphrey',
#  '7681': 'Terry Mcknight',
#  '1217': 'Robert Compton',
#  '4308': 'William Smith',
#  '9403': 'Mary Peters',
#  '12410': 'Bryan Smith',
#  '11600': 'Jean Finley',
#  '6934': 'Mary Ellis',
#  '11149': 'Roy Smith',
#  '3519': 'Nicholas Ruiz',
#  '438': 'Diane Smith',
#  '8071': 'Gary Baker',
#  '6285': 'Mary Garcia',
#  '1419': 'Mary Black',
#  '4158': 'Tyler Smith',
#  '5125': 'Mary Miller',
#  '11221': 'Mary Pittman',
#  '5412': 'Roger Smith',
#  '10365': 'Amy Smith',
#  '8522': 'Mary Smith',
#  '3804': 'Andrew Le',
#  '2915': 'Sandra Green',
#  '7074': 'Mary Patton',
#  '1912': 'Robert Nunez',
#  '6027': 'Mary Moore',
#  '4456': 'Evelyn Spencer',
#  '13': 'Mary Baldwin',
#  '1785': 'Mary Smith',
#  '2548': 'Mary Curtis',
#  '2670': 'Mary Smith',
#  '3054': 'Gregory Pope',
#  '10054': 'Zachary Hunt',
#  '9330': 'Mary Conley',
#  '11482': 'Mary Smith',
#  '10832': 'Mary Khan',
#  '9934': 'Kathleen Smith',
#  '10528': 'Mary Smith',
#  '9608': 'Jack Lewis',
#  '8336': 'Mary Smith',
#  '10816': 'Henry Turner',
#  '11398': 'Brian Smith',
#  '2705': 'Mary Smith',
#  '8134': 'Doris Smith',
#  '8758': 'Mary Shelton',
#  '5301': 'Mary Ward',
#  '10761': 'David Smith',
#  '7176': 'Mary Hudson',
#  '152': 'Mary Smith',
#  '10150': 'Mary Vasquez',
#  '3458': 'Henry Smith',
#  '7733': 'Mary Torres',
#  '5351': 'Mary Smith',
#  '1302': 'Alice Edwards',
#  '1627': 'Mary Gonzales',
#  '12369': 'Mary Martinez',
#  '3255': 'Mary Christian',
#  '4633': 'Mary Smith',
#  '1817': 'Teresa Mitchell',
#  '3745': 'Kimberly Smith',
#  '6660': 'Christine Smith',
#  '2905': 'Kelly Livingston',
#  '414': 'Pamela Smith',
#  '7408': 'Mary Holmes',
#  '4181': 'Aaron Hudson',
#  '312': 'Jack Smith',
#  '7192': 'Mary Bowers',
#  '2284': 'Mary Shaffer',
#  '9775': 'Katherine Smith',
#  '10559': 'Mary Jones',
#  '5809': 'Mary Nunez',
#  '3929': 'Amanda Levy',
#  '2683': 'Mary Gallegos',
#  '9633': 'Catherine Smith',
#  '5603': 'David Smith',
#  '11125': 'Edward Fitzgerald',
#  '6212': 'Mary Smith',
#  '500': 'Nicholas Smith',
#  '1010': 'Carolyn Moss',
#  '8512': 'Deborah Gonzalez',
#  '2833': 'Eric Vega',
#  '10465': 'Cynthia Spence',
#  '2082': 'Megan Holland',
#  '268': 'Mary Miller',
#  '98': 'William Smith',
#  '11650': 'Mary Smith',
#  '2058': 'Mary Hernandez',
#  '11701': 'Mary Tucker',
#  '611': 'Lisa Cross',
#  '3552': 'Kathleen Smith',
#  '4878': 'Sandra Smith',
#  '11498': 'Scott Day',
#  '11609': 'Alice Lozano',
#  '5308': 'Mary Smith',
#  '7425': 'Rebecca Smith',
#  '5611': 'Michael Williamson',
#  '2738': 'Amber Holmes',
#  '8731': 'Donna Allen',
#  '24': 'Mary Smith',
#  '7346': 'Mary Hughes',
#  '8254': 'Jesse Esparza',
#  '545': 'Joe Andrade',
#  '5759': 'Mary Brown',
#  '11917': 'Matthew Brooks',
#  '5641': 'Eric Cohen',
#  '5479': 'Mary Smith',
#  '3621': 'Mary West',
#  '9473': 'Michelle Smith',
#  '12108': 'Gloria Stephens',
#  '2730': 'Mary Baldwin',
#  '11619': 'Mary Anderson',
#  '1510': 'Mary Smith',
#  '11063': 'Mary Smith',
#  '2250': 'Amanda Smith',
#  '10173': 'Kathleen Smith',
#  '8280': 'Mary Tyler',
#  '5806': 'Mary Smith',
#  '3132': 'Mary Gutierrez',
#  '7784': 'Mary Smith',
#  '12150': 'Paul Hancock',
#  '12363': 'Kimberly Meza',
#  '11883': 'Steven Miller',
#  '2935': 'Mary Smith',
#  '1581': 'Mary Smith',
#  '7599': 'Gerald Smith',
#  '8973': 'Mary Smith',
#  '10538': 'Evelyn Gomez',
#  '2577': 'Mary Tucker',
#  '9942': 'Lisa Moore',
#  '3189': 'Bryan Smith',
#  '5690': 'Mary Smith',
#  '8375': 'John Smith',
#  '3317': 'Betty Smith',
#  '660': 'Shirley Baker',
#  '547': 'Kathleen Contreras',
#  '8659': 'Brenda Wong',
#  '11692': 'Mary Weber',
#  '9001': 'Mary Smith',
#  '3242': 'Mary Garcia',
#  '5253': 'Susan Watkins',
#  '10647': 'Amy Johnson',
#  '2042': 'Sara Castro',
#  '2531': 'Mary Fitzpatrick',
#  '1898': 'Mary Hammond',
#  '2035': 'Mary Salas',
#  '9458': 'Mary Carlson',
#  '3222': 'Mary Williams',
#  '11079': 'Russell Smith',
#  '3372': 'Virginia Smith',
#  '4314': 'Catherine Curry',
#  '6617': 'Mary Barnes',
#  '4729': 'Robert Kaufman',
#  '4716': 'Edward Cooper',
#  '9601': 'Olivia Reid',
#  '8645': 'Andrew Johnston',
#  '2928': 'Sarah Larsen',
#  '2069': 'Alice Ellison',
#  '10304': 'Mary Watson',
#  '7795': 'Sandra Smith',
#  '4268': 'Ruth Deleon',
#  '10106': 'Mary Smith',
#  '4152': 'Deborah Martinez',
#  '2175': 'Mary Smith',
#  '11540': 'Doris Smith',
#  '12072': 'Mary Stevens',
#  '6679': 'Cynthia Smith',
#  '7279': 'Emily Smith',
#  '2321': 'Mary Patel',
#  '10729': 'Mary Phillips',
#  '10981': 'Mary Smith',
#  '7457': 'Cheryl Smith',
#  '10895': 'Mary Pierce',
#  '5406': 'Mary Whitehead',
#  '9115': 'Gary Clayton',
#  '7848': 'Jessica Smith',
#  '3823': 'Charles Ortega',
#  '7308': 'Teresa Jensen',
#  '11740': 'Jacob Foster',
#  '576': 'Arthur Fisher',
#  '3339': 'Mary Payne',
#  '3865': 'Jessica Hunter',
#  '10811': 'Joshua Carter',
#  '12336': 'Joe Smith',
#  '699': 'Raymond Richards',
#  '9338': 'James Davis',
#  '8744': 'Mary Wells',
#  '5250': 'Donald Smith',
#  '361': 'Alexander Shaw',
#  '4097': 'Russell Smith',
#  '9767': 'Mary Clayton',
#  '1824': 'Julia Tucker',
#  '11288': 'Cynthia Smith',
#  '6415': 'Terry Carpenter',
#  '7251': 'Benjamin Hamilton',
#  '5032': 'Christopher Fry',
#  '10612': 'Anna Smith',
#  '7853': 'Aaron Smith',
#  '8157': 'Mary Marshall',
#  '4315': 'Mary Smith',
#  '3235': 'Lori Baker',
#  '3311': 'Ryan Shelton',
#  '7931': 'Mary Mcdaniel',
#  '4329': 'Mary Ayala',
#  '7051': 'Russell Smith',
#  '11784': 'Mary Cunningham',
#  '4926': 'Mary Smith',
#  '1574': 'Mary Smith',
#  '1083': 'Mary Herman',
#  '7082': 'Adam Blair',
#  '4447': 'Mary Wyatt',
#  '73': 'Mary Smith',
#  '663': 'Mary Smith',
#  '5497': 'Katherine Skinner',
#  '7186': 'Mary Meadows',
#  '6558': 'Ethan Smith',
#  '11980': 'Samuel Swanson',
#  '6458': 'Jonathan Franco',
#  '8295': 'Margaret Lynch',
#  '2476': 'Gerald Smith',
#  '4488': 'Frances Smith',
#  '7367': 'Joseph Smith',
#  '2571': 'Zachary Beasley',
#  '2087': 'Mary Burton',
#  '5472': 'Joyce Vance',
#  '10339': 'Steven Smith',
#  '2676': 'Jeffrey Smith',
#  '10246': 'Barbara Cameron',
#  '3795': 'Peter Williams',
#  '11694': 'Margaret Rios',
#  '11305': 'Mary Hartman',
#  '5179': 'Robert Smith',
#  '3763': 'Mary Martinez',
#  '3697': 'Mary Hobbs',
#  '8178': 'Mary Barnes',
#  '828': 'Johnny Herrera',
#  '1221': 'Mary Smith',
#  '3766': 'David Chavez',
#  '7684': 'Evelyn Harper',
#  '11450': 'Donald Nelson',
#  '821': 'Daniel Clayton',
#  '4220': 'Mary Morgan',
#  '11819': 'Jerry Vincent',
#  '10926': 'Mary Smith',
#  '7914': 'Mary Smith',
#  '1269': 'Mary Young',
#  '3969': 'Carl Smith',
#  '6968': 'Mary Sims',
#  '4372': 'Mary Smith',
#  '11506': 'Sara Baxter',
#  '5905': 'Denise Smith',
#  '11967': 'Mary Beard',
#  '7680': 'Sandra Heath',
#  '12298': 'Mary Harper',
#  '964': 'Mary Frazier',
#  '9555': 'Sandra Smith',
#  '4559': 'Margaret Mcdaniel',
#  '8493': 'Mark Pena',
#  '10580': 'Andrew Smith',
#  '10629': 'Robert Smith',
#  '10608': 'Ralph Kidd',
#  '11136': 'Gloria Smith',
#  '3828': 'Janice Carpenter',
#  '4776': 'Mary Potter',
#  '3240': 'Kelly Golden',
#  '11183': 'Mary Smith',
#  '10157': 'Mary Todd',
#  '7036': 'Maria Smith',
#  '7542': 'Mary Moss',
#  '1557': 'Nicole Bolton',
#  '11583': 'Mary Smith',
#  '5683': 'Rachel Smith',
#  '10890': 'Doris Moody',
#  '12025': 'Linda Collier',
#  '4695': 'Hannah Guerra',
#  '970': 'Mary Alvarez',
#  '3808': 'Nancy Smith',
#  '8676': 'Mary Nguyen',
#  '7772': 'Mary Thompson',
#  '12324': 'Ruth Townsend',
#  '4546': 'Mary Garcia',
#  '3481': 'Ronald Obrien',
#  '1322': 'Aaron Williamson',
#  '1655': 'Arthur Hunter',
#  '10783': 'Linda Smith',
#  '11264': 'George Smith',
#  '12044': 'Mary Smith',
#  '8504': 'Mary Davis',
#  '10003': 'Robert Kerr',
#  '11667': 'Mary Brooks',
#  '5893': 'Mary Young',
#  '11025': 'Mary Smith',
#  '1682': 'Mary Hall',
#  '8583': 'Amber Clay',
#  '7145': 'Mary Smith',
#  '1684': 'Anna Smith',
#  '1160': 'Mary Randolph',
#  '267': 'Richard Smith',
#  '11499': 'Mary Smith',
#  '2569': 'Mary Duncan',
#  '3357': 'Mary Smith',
#  '9488': 'Mary Smith',
#  '9067': 'Harry Myers',
#  '11535': 'Dorothy Moon',
#  '6488': 'Mary Smith',
#  '10202': 'Mary Wagner',
#  '8696': 'Mary Pope',
#  '11827': 'Mary Smith',
#  '10973': 'Debra Sullivan',
#  '4873': 'Samantha Wilson',
#  '3390': 'Elizabeth Stephenson',
#  '289': 'Diana Richards',
#  '5275': 'Alan Smith',
#  '559': 'Paul Melton',
#  '330': 'Mary Smith',
#  '7954': 'Danielle Smith',
#  '5063': 'Frank Smith',
#  '3156': 'Kathleen Smith',
#  '8615': 'Mary Smith',
#  '627': 'Robert Smith',
#  '4565': 'Marilyn Stone',
#  '1541': 'Victoria Smith',
#  '9788': 'Mary Smith',
#  '7794': 'Jennifer Compton',
#  '5792': 'Mary Smith',
#  '1339': 'Melissa Mack',
#  '7766': 'Jack Smith',
#  '9034': 'Paul Villa',
#  '1759': 'Mary Barnett',
#  '11089': 'Mary Smith',
#  '1279': 'Alexander Williams',
#  '3627': 'Mary Smith',
#  '10340': 'Nicholas Stevens',
#  '7400': 'Benjamin Smith',
#  '8331': 'Mary Norman',
#  '2561': 'Angela Smith',
#  '11693': 'Mary Garrett',
#  '3459': 'Mary Wright',
#  '2875': 'Mary Roberts',
#  '2937': 'Mary Mcclure',
#  '3252': 'Mary Smith',
#  '9580': 'Mary Robbins',
#  '4061': 'Jeffrey Houston',
#  '4764': 'Christopher Smith',
#  '2023': 'Mary Fox',
#  '10940': 'Mary Crawford',
#  '11712': 'Edward Smith',
#  '198': 'Mary Joseph',
#  '10471': 'Mary Smith',
#  '1887': 'Katherine Jenkins',
#  '1636': 'Julie Petersen',
#  ...}

# %%
type(custDictBroadcast.value)
# Out:
# dict

# %%
custDictBroadcast.value['6342']
# Out:
# 'Kimberly Blair'

# %%
custDictBroadcast.value['11599']

# %% [markdown]
# Since some customer details are missing in the customers files we better use .get method to get the customer name for a given customer id.

# %% [markdown]
# Read the salestxns data input file to create another input RDD

# %%
salesRDD1=sc.textFile("salestxns.tsv")

# %% [markdown]
# Display count and a sample of the RDD elements for debugging purposes. The RDD elements are the lines of type string from the input file.

# %%
salesRDD1.count()
# Out:
# 172198

# %%
salesRDD1.take(3)
# Out:
# ["1\t43\tCamping & Hiking\t957\tDiamondback Women's Serene Classic Comfort Bi\t299.98\t1\t11599",
#  '2\t48\tWater Sports\t1073\tPelican Sunstream 100 Kayak\t199.99\t1\t256',
#  "3\t24\tWomen's Apparel\t502\tNike Men's Dri-FIT Victory Golf Polo\t50\t5\t256"]

# %% [markdown]
# ###### We need to transform the RDD elements into key,value pairs with the required key and value.
#
# The function for salesRDD:
#  - Splits the input string at tabs.
#  - Uses a tuple containing customer id, product id, product name and product price as the key and product quantity as the value
#  - Then returns the string constructed as pair RDD
#  - Later in the code we will use reduceByKey to sum up the quantities of same product bought by same customer in separate multiple transactions

# %%
def make_sales_pairRDD(str):
    line = str.split('\t')
    return ((line[7],line[3],line[4],line[5]), int(line[6]))

# %%
salesRDD2=salesRDD1.map(lambda line: make_sales_pairRDD(line))

# %% [markdown]
# Display the RDD2 elements for debug purposes.

# %% [markdown]
# Since sales RDD is more than 100 times larger than customer RDD we can increase the parallelism  by increasing the partitions using partitionBy.
# PySpark uses a default partitioner in this case.

# %%
salesRDD2.partitionBy(10).persist()
# Out:
# MapPartitionsRDD[11] at mapPartitions at PythonRDD.scala:133

# %%
salesRDD2.count()
# Out:
# 172198

# %%
salesRDD3 = salesRDD2.reduceByKey(lambda va,vb: va+vb)

# %%
salesRDD3.count()
# Out:
# 92875

# %%
salesRDD3.take(3)
# Out:
# [(('11599', '957', "Diamondback Women's Serene Classic Comfort Bi", '299.98'),
#   1),
#  (('256', '403', "Nike Men's CJ Elite 2 TD Football Cleat", '129.99'), 4),
#  (('8827', '365', 'Perfect Fitness Perfect Rip Deck', '59.99'), 12)]

# %% [markdown]
# Map the key and value in each element of salesRDD3 so that we have customer id, product id, product name, price, total quantity purchased and lastly total amount paid (price * total qty).
# Once that is done we can use the broadcast variable to get the customer name as required for the final format mentioned in the problem statement.

# %%
salesRDD4=salesRDD3.map(lambda fld : (fld[0][0],fld[0][1],fld[0][2],float(fld[0][3]),fld[1], 
                                      round(float(fld[0][3])*fld[1],2)))

# %%
salesRDD4.take(20)
# Out:
# [('11599',
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   1,
#   299.98),
#  ('256', '403', "Nike Men's CJ Elite 2 TD Football Cleat", 129.99, 4, 519.96),
#  ('8827', '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 12, 719.88),
#  ('8827', '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 3, 150.0),
#  ('11318', '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 2, 99.96),
#  ('11318',
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   3,
#   389.97),
#  ('4530', '1073', 'Pelican Sunstream 100 Kayak', 199.99, 2, 399.98),
#  ('4530',
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   4,
#   1199.92),
#  ('4530', '926', 'Glove It Imperial Golf Towel', 15.99, 5, 79.95),
#  ('2911', '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 10, 499.8),
#  ('5648', '1073', 'Pelican Sunstream 100 Kayak', 199.99, 6, 1199.94),
#  ('918', '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 4, 239.96),
#  ('918', '191', "Nike Men's Free 5.0+ Running Shoe", 99.99, 7, 699.93),
#  ('1837',
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   1,
#   299.98),
#  ('1837', '134', "Nike Women's Legend V-Neck T-Shirt", 25.0, 4, 100.0),
#  ('1837', '191', "Nike Men's Free 5.0+ Running Shoe", 99.99, 5, 499.95),
#  ('1837', '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 12, 600.0),
#  ('9149', '276', "Under Armour Women's Ignite Slide", 31.99, 4, 127.96),
#  ('9842', '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 8, 399.84),
#  ('2568', '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 10, 500.0)]

# %%
type(salesRDD3.first())
# Out:
# tuple

# %%
salesRDD5=salesRDD4.map(lambda fld : (fld[0],custDictBroadcast.value.get(fld[0]),fld[1],fld[2],fld[3],fld[4],fld[5]))

# %%
salesRDD5.take(100)
# Out:
# [('3730', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 3, 179.97),
#  ('3730', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 2, 100.0),
#  ('3730',
#   None,
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   4,
#   1199.92),
#  ('3925',
#   None,
#   '502',
#   "Nike Men's Dri-FIT Victory Golf Polo",
#   50.0,
#   15,
#   750.0),
#  ('8743', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 7, 349.86),
#  ('8743',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   3,
#   389.97),
#  ('2640',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   4,
#   519.96),
#  ('2640', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 1, 49.98),
#  ('5004',
#   None,
#   '1014',
#   "O'Brien Men's Neoprene Life Vest",
#   49.98,
#   31,
#   1549.38),
#  ('5004',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   5,
#   649.95),
#  ('6413',
#   None,
#   '627',
#   "Under Armour Girls' Toddler Spine Surge Runni",
#   39.99,
#   3,
#   119.97),
#  ('6413', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 6, 299.88),
#  ('11132',
#   None,
#   '627',
#   "Under Armour Girls' Toddler Spine Surge Runni",
#   39.99,
#   10,
#   399.9),
#  ('10142',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   6,
#   779.94),
#  ('4799',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   3,
#   389.97),
#  ('2598',
#   None,
#   '627',
#   "Under Armour Girls' Toddler Spine Surge Runni",
#   39.99,
#   2,
#   79.98),
#  ('2598', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 5, 249.9),
#  ('3391',
#   None,
#   '823',
#   'Titleist Pro V1x High Numbers Personalized Go',
#   51.99,
#   2,
#   103.98),
#  ('9188',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   1,
#   129.99),
#  ('5316', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 24, 1439.76),
#  ('9281',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   2,
#   259.98),
#  ('12164',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   1,
#   129.99),
#  ('1454', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 5, 249.9),
#  ('12210',
#   None,
#   '627',
#   "Under Armour Girls' Toddler Spine Surge Runni",
#   39.99,
#   14,
#   559.86),
#  ('12210',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   3,
#   389.97),
#  ('12210', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 2, 99.96),
#  ('9003',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   4,
#   1599.92),
#  ('9003',
#   None,
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   4,
#   1199.92),
#  ('9003', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 3, 179.97),
#  ('7773',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   1,
#   399.98),
#  ('7773', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 3, 150.0),
#  ('1263',
#   None,
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   3,
#   899.94),
#  ('1263', None, '191', "Nike Men's Free 5.0+ Running Shoe", 99.99, 2, 199.98),
#  ('1241',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   2,
#   799.96),
#  ('12210',
#   None,
#   '828',
#   'Bridgestone e6 Straight Distance NFL San Dieg',
#   31.99,
#   5,
#   159.95),
#  ('5659', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 5, 299.95),
#  ('5659',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   2,
#   799.96),
#  ('8307', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 4, 239.96),
#  ('8307',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   1,
#   399.98),
#  ('8307', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 5, 250.0),
#  ('1107',
#   None,
#   '502',
#   "Nike Men's Dri-FIT Victory Golf Polo",
#   50.0,
#   17,
#   850.0),
#  ('1107',
#   None,
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   1,
#   299.98),
#  ('2158',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   2,
#   259.98),
#  ('2249',
#   None,
#   '627',
#   "Under Armour Girls' Toddler Spine Surge Runni",
#   39.99,
#   2,
#   79.98),
#  ('7572',
#   None,
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   1,
#   299.98),
#  ('7572',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   2,
#   799.96),
#  ('2613',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   5,
#   649.95),
#  ('2613', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 5, 249.9),
#  ('4398', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 4, 239.96),
#  ('12226',
#   None,
#   '822',
#   'Titleist Pro V1x High Numbers Golf Balls',
#   47.99,
#   2,
#   95.98),
#  ('12226',
#   None,
#   '627',
#   "Under Armour Girls' Toddler Spine Surge Runni",
#   39.99,
#   2,
#   79.98),
#  ('4930', None, '191', "Nike Men's Free 5.0+ Running Shoe", 99.99, 7, 699.93),
#  ('12101', None, '793', "Hirzl Women's Hybrid Golf Glove", 14.99, 2, 29.98),
#  ('12101',
#   None,
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   3,
#   899.94),
#  ('2774', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 19, 1139.81),
#  ('2774',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   8,
#   3199.84),
#  ('6009',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   2,
#   799.96),
#  ('6009', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 4, 200.0),
#  ('9106',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   2,
#   799.96),
#  ('9106', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 7, 350.0),
#  ('9106',
#   None,
#   '957',
#   "Diamondback Women's Serene Classic Comfort Bi",
#   299.98,
#   1,
#   299.98),
#  ('3878', None, '191', "Nike Men's Free 5.0+ Running Shoe", 99.99, 6, 599.94),
#  ('3878', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 1, 59.99),
#  ('11400',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   3,
#   389.97),
#  ('9622', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 10, 599.9),
#  ('9622', None, '1073', 'Pelican Sunstream 100 Kayak', 199.99, 2, 399.98),
#  ('7780', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 11, 549.78),
#  ('5007',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   2,
#   799.96),
#  ('5007', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 5, 250.0),
#  ('10832',
#   'Mary Khan',
#   '365',
#   'Perfect Fitness Perfect Rip Deck',
#   59.99,
#   8,
#   479.92),
#  ('10832',
#   'Mary Khan',
#   '926',
#   'Glove It Imperial Golf Towel',
#   15.99,
#   4,
#   63.96),
#  ('9884', None, '191', "Nike Men's Free 5.0+ Running Shoe", 99.99, 5, 499.95),
#  ('9884', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 1, 59.99),
#  ('3202', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 14, 839.86),
#  ('6379', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 10, 599.9),
#  ('6379', None, '191', "Nike Men's Free 5.0+ Running Shoe", 99.99, 6, 599.94),
#  ('1735',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   3,
#   1199.94),
#  ('1735', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 4, 200.0),
#  ('1263', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 3, 179.97),
#  ('6120', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 5, 299.95),
#  ('6120',
#   None,
#   '502',
#   "Nike Men's Dri-FIT Victory Golf Polo",
#   50.0,
#   16,
#   800.0),
#  ('2403',
#   None,
#   '627',
#   "Under Armour Girls' Toddler Spine Surge Runni",
#   39.99,
#   6,
#   239.94),
#  ('2403',
#   None,
#   '567',
#   "adidas Men's Germany Black Crest Away Tee",
#   25.0,
#   1,
#   25.0),
#  ('8512',
#   'Deborah Gonzalez',
#   '1014',
#   "O'Brien Men's Neoprene Life Vest",
#   49.98,
#   3,
#   149.94),
#  ('2078', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 15, 749.7),
#  ('7940',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   4,
#   1599.92),
#  ('7940', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 9, 450.0),
#  ('10071',
#   None,
#   '502',
#   "Nike Men's Dri-FIT Victory Golf Polo",
#   50.0,
#   11,
#   550.0),
#  ('2374', None, '1073', 'Pelican Sunstream 100 Kayak', 199.99, 3, 599.97),
#  ('2374', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 1, 59.99),
#  ('11933', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 3, 179.97),
#  ('11933', None, '1073', 'Pelican Sunstream 100 Kayak', 199.99, 2, 399.98),
#  ('7021',
#   None,
#   '1004',
#   'Field & Stream Sportsman 16 Gun Fire Safe',
#   399.98,
#   4,
#   1599.92),
#  ('7021', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 2, 119.98),
#  ('7021',
#   None,
#   '810',
#   "Glove It Women's Mod Oval Golf Glove",
#   19.99,
#   3,
#   59.97),
#  ('9418',
#   'Debra Snow',
#   '1014',
#   "O'Brien Men's Neoprene Life Vest",
#   49.98,
#   3,
#   149.94),
#  ('9418',
#   'Debra Snow',
#   '627',
#   "Under Armour Girls' Toddler Spine Surge Runni",
#   39.99,
#   7,
#   279.93),
#  ('9418',
#   'Debra Snow',
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   4,
#   519.96),
#  ('4439',
#   None,
#   '403',
#   "Nike Men's CJ Elite 2 TD Football Cleat",
#   129.99,
#   1,
#   129.99),
#  ('4439',
#   None,
#   '627',
#   "Under Armour Girls' Toddler Spine Surge Runni",
#   39.99,
#   3,
#   119.97)]

# %%
for line in salesRDD5.take(30):
    print(line)
# Out:
# ('11599', None, '957', "Diamondback Women's Serene Classic Comfort Bi", 299.98, 1, 299.98)
# ('256', None, '403', "Nike Men's CJ Elite 2 TD Football Cleat", 129.99, 4, 519.96)
# ('8827', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 12, 719.88)
# ('8827', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 3, 150.0)
# ('11318', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 2, 99.96)
# ('11318', None, '403', "Nike Men's CJ Elite 2 TD Football Cleat", 129.99, 3, 389.97)
# ('4530', None, '1073', 'Pelican Sunstream 100 Kayak', 199.99, 2, 399.98)
# ('4530', None, '957', "Diamondback Women's Serene Classic Comfort Bi", 299.98, 4, 1199.92)
# ('4530', None, '926', 'Glove It Imperial Golf Towel', 15.99, 5, 79.95)
# ('2911', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 10, 499.8)
# ('5648', None, '1073', 'Pelican Sunstream 100 Kayak', 199.99, 6, 1199.94)
# ('918', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 4, 239.96)
# ('918', None, '191', "Nike Men's Free 5.0+ Running Shoe", 99.99, 7, 699.93)
# ('1837', None, '957', "Diamondback Women's Serene Classic Comfort Bi", 299.98, 1, 299.98)
# ('1837', None, '134', "Nike Women's Legend V-Neck T-Shirt", 25.0, 4, 100.0)
# ('1837', None, '191', "Nike Men's Free 5.0+ Running Shoe", 99.99, 5, 499.95)
# ('1837', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 12, 600.0)
# ('9149', None, '276', "Under Armour Women's Ignite Slide", 31.99, 4, 127.96)
# ('9842', None, '1014', "O'Brien Men's Neoprene Life Vest", 49.98, 8, 399.84)
# ('2568', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 10, 500.0)
# ('2568', None, '1073', 'Pelican Sunstream 100 Kayak', 199.99, 3, 599.97)
# ('2568', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 3, 179.97)
# ('2568', None, '1004', 'Field & Stream Sportsman 16 Gun Fire Safe', 399.98, 1, 399.98)
# ('2667', None, '810', "Glove It Women's Mod Oval Golf Glove", 19.99, 4, 79.96)
# ('2667', None, '1073', 'Pelican Sunstream 100 Kayak', 199.99, 3, 599.97)
# ('2667', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 18, 1079.82)
# ('1205', None, '1073', 'Pelican Sunstream 100 Kayak', 199.99, 3, 599.97)
# ('1205', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 13, 779.87)
# ('9198', None, '502', "Nike Men's Dri-FIT Victory Golf Polo", 50.0, 6, 300.0)
# ('9198', None, '365', 'Perfect Fitness Perfect Rip Deck', 59.99, 24, 1439.76)

# %%
salesRDD5.saveAsTextFile('cust_sales55')

# %% [markdown]
# The above code has several print statements for illustration and for debug purposes. Also, some of the code can be improved. For example we do not need salesRDD5. We can get the required result without creating it thus reducing one transformation. Figure out any other such improvements and rewrite the code.

# %% [markdown]
# Also figure out how you can get the same output when you use join the two RDDs (customers and salestxns)
